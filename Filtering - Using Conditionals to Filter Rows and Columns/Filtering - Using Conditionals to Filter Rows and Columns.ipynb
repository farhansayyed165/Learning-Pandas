# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='ResponseId')
sch_df = pd.read_csv('survey_results_schema.csv', index_col='qname' )

# %%
pd.set_option('display.max_columns', 80)
pd.set_option('display.max_rows', 80)

# %%
sch_df.head(10)
# Out:
#                      qid                                           question  \
# qname
# S0                 QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo           QID12                                  Browser Meta Info
# S1                  QID1  <span style="font-size:22px; font-family: aria...
# MainBranch          QID2  Which of the following options best describes ...
# Employment        QID296  Which of the following best describes your cur...
# RemoteWork        QID308  Which best describes your current work situation?
# CodingActivities  QID297  Which of the following best describes the code...
# S2                QID190  <span style="font-size:22px; font-family: aria...
# EdLevel            QID25  Which of the following best describes the high...
# LearnCode         QID276  How did you learn to code? Select all that apply.
#
#                  force_resp  type selector
# qname
# S0                    False    DB       TB
# ...

# %%
df.head(3)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# ResponseId
# 1                                                NaN
# 2           Hobby;Contribute to open-source projects
# 3                                              Hobby
#
#                                                     EdLevel  \
# ResponseId
# 1                                                       NaN
# ...

# %%
hi_salary = (df['ConvertedCompYearly'] > 70000)

# %%
df.loc[hi_salary,['Country','LanguageHaveWorkedWith','ConvertedCompYearly']]
# Out:
#                                                       Country  \
# ResponseId
# 4                                                      Israel
# 12                                   United States of America
# 15                                   United States of America
# 18                                                    Austria
# 23                                                     Canada
# ...                                                       ...
# 73108                                                  Brazil
# 73112                                United States of America
# 73114                                United States of America
# 73117                                United States of America
# 73122       United Kingdom of Great Britain and Northern I...
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 4                                C#;JavaScript;SQL;TypeScript
# 12          C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL
# ...

# %%
countries = ['United States of America', 'India', 'United Kingdom', 'Germany', 'Canada']
filt = (df['Country'].isin(countries))

# %%
df.loc[filt,['Country']]
# Out:
#                              Country
# ResponseId
# 2                             Canada
# 5           United States of America
# 6                            Germany
# 7                              India
# 8                              India
# ...                              ...
# 73259                          India
# 73263                        Germany
# 73265       United States of America
# 73266       United States of America
# 73268                         Canada
#
# [28067 rows x 1 columns]

# %%
filt2 = df['LanguageHaveWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt2,'LanguageHaveWorkedWith']
# Out:
# ResponseId
# 3                        C#;C++;HTML/CSS;JavaScript;Python
# 7            C++;HTML/CSS;JavaScript;PHP;Python;TypeScript
# 12       C#;HTML/CSS;JavaScript;PowerShell;Python;Rust;SQL
# 15             HTML/CSS;JavaScript;PHP;Python;R;Ruby;Scala
# 17                                    C#;Java;PHP;Python;R
#                                ...
# 73258                                         C;Python;SQL
# 73262    Bash/Shell;HTML/CSS;Java;JavaScript;Python;SQL...
# 73264    Bash/Shell;Dart;JavaScript;PHP;Python;SQL;Type...
# 73265            Bash/Shell;HTML/CSS;JavaScript;Python;SQL
# 73266                   HTML/CSS;JavaScript;PHP;Python;SQL
# Name: LanguageHaveWorkedWith, Length: 34155, dtype: object
