# %%
details = {
    'Name' : ['Ankit', 'Aishwarya', 'Shaurya', 'Shivangi'],
    'Age' : [23, 21, 22, 21],
    'University' : ['BHU', 'JNU', 'DU', 'BHU'],
}

# %%
data = pd.DataFrame(details)

# %%
data
# Out:
#         Name  Age University
# 0      Ankit   23        BHU
# 1  Aishwarya   21        JNU
# 2    Shaurya   22         DU
# 3   Shivangi   21        BHU

# %%
data['Name']
# Out:
# 0        Ankit
# 1    Aishwarya
# 2      Shaurya
# 3     Shivangi
# Name: Name, dtype: object

# %%
type(data['Name'])
# Out:
# pandas.core.series.Series

# %%
data.columns
# Out:
# Index(['Name', 'Age', 'University'], dtype='object')

# %%
data.iloc[[0,1],2]
# Out:
# 0    BHU
# 1    JNU
# Name: University, dtype: object

# %%
data.loc[0]
# Out:
# Name          Ankit
# Age              23
# University      BHU
# Name: 0, dtype: object

# %%
data.loc[[0,2], ['Age', 'Name']]
# Out:
#    Age     Name
# 0   23    Ankit
# 2   22  Shaurya

# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv')
sch_df = pd.read_csv('survey_results_schema.csv')

# %%
pd.set_option('display.max_columns', 78)
pd.set_option('display.max_rows', 73267)

# %%
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
sch_df
# Out:
#        qid                 qname  \
# 0    QID16                    S0
# 1    QID12              MetaInfo
# 2     QID1                    S1
# 3     QID2            MainBranch
# 4   QID296            Employment
# 5   QID308            RemoteWork
# 6   QID297      CodingActivities
# 7   QID190                    S2
# 8    QID25               EdLevel
# 9   QID276             LearnCode
# 10  QID281       LearnCodeOnline
# 11  QID306  LearnCodeCoursesCert
# 12   QID32             YearsCode
# 13   QID34          YearsCodePro
# 14   QID31               DevType
# 15   QID29               OrgSize
# 16  QID278     PurchaseInfluence
# 17  QID279            BuyNewTool
# 18    QID6               Country
# 19   QID50              Currency
# 20   QID51             CompTotal
# 21   QID52              CompFreq
# 22   QID61                    S3
# 23  QID233              Language
# 24  QID262              Database
# 25  QID263              Platform
# 26  QID264              Webframe
# ...

# %%
df.shape
# Out:
# (73268, 79)

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
df['Sexuality']
# Out:
# 0                            NaN
# 1                            NaN
# 2                       Bisexual
# 3        Straight / Heterosexual
# 4                            NaN
#                   ...
# 73263    Straight / Heterosexual
# 73264    Straight / Heterosexual
# 73265    Straight / Heterosexual
# 73266    Straight / Heterosexual
# 73267    Straight / Heterosexual
# Name: Sexuality, Length: 73268, dtype: object

# %%
## Most People who code are straight
df['Sexuality'].value_counts()
# Out:
# Straight / Heterosexual                                                           55238
# Prefer not to say                                                                  4350
# Bisexual                                                                           2700
# Gay or Lesbian                                                                     1382
# Prefer to self-describe:                                                           1079
# Queer                                                                               394
# Bisexual;Straight / Heterosexual                                                    354
# Bisexual;Queer                                                                      282
# Straight / Heterosexual;Prefer to self-describe:                                    169
# Gay or Lesbian;Queer                                                                150
# Straight / Heterosexual;Queer                                                        79
# ...

# %%
df.loc[0:10,'Sexuality':'MentalHealth']
# Out:
#                    Sexuality               Ethnicity           Accessibility  \
# 0                        NaN                     NaN                     NaN
# 1                        NaN                     NaN                     NaN
# 2                   Bisexual                   White       None of the above
# 3    Straight / Heterosexual                   White       None of the above
# 4                        NaN                     NaN                     NaN
# 5   Prefer to self-describe:  Or, in your own words:  Or, in your own words:
# 6                        NaN                  Indian       None of the above
# 7    Straight / Heterosexual                  Indian       None of the above
# 8   Prefer to self-describe:                European  Or, in your own words:
# 9    Straight / Heterosexual          White;European       None of the above
# 10   Straight / Heterosexual                European       None of the above
#
# ...
