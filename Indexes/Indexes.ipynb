# %%
import pandas as pd

# %%
people = {
    "first": ["Farhan", 'Party', 'John'], 
    "last": ["Doe", 'Animal', 'Cena'], 
    "email": ["farhandoe@doeservice.com", 'guy@gmail.com', 'ucantseeme@cena.com']
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#     first    last                     email
# 0  Farhan     Doe  farhandoe@doeservice.com
# 1   Party  Animal             guy@gmail.com
# 2    John    Cena       ucantseeme@cena.com

# %%
df['email']
# Out:
# 0    farhandoe@doeservice.com
# 1               guy@gmail.com
# 2         ucantseeme@cena.com
# Name: email, dtype: object

# %%
## Let's set emails as indexes

# %%
df.set_index('email', inplace=True)

# %%
df
# Out:
#                            first    last
# email
# farhandoe@doeservice.com  Farhan     Doe
# guy@gmail.com              Party  Animal
# ucantseeme@cena.com         John    Cena

# %%
df.index
# Out:
# Index(['farhandoe@doeservice.com', 'guy@gmail.com', 'ucantseeme@cena.com'], dtype='object', name='email')

# %%
df.loc['guy@gmail.com']
# Out:
# first     Party
# last     Animal
# Name: guy@gmail.com, dtype: object

# %%
df.loc['guy@gmail.com', 'last']
# Out:
# 'Animal'

# %%
df.reset_index(inplace=True)
df
# Out:
#                       email   first    last
# 0  farhandoe@doeservice.com  Farhan     Doe
# 1             guy@gmail.com   Party  Animal
# 2       ucantseeme@cena.com    John    Cena

# %%
df = pd.read_csv('survey_results_public.csv', index_col='ResponseId')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)
df.head(3)
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                                               None of these
# 2                              I am a developer by profession
# 3           I am not primarily a developer, but I write co...
#
#                      Employment                            RemoteWork  \
# ResponseId
# 1                           NaN                                   NaN
# 2           Employed, full-time                          Fully remote
# 3           Employed, full-time  Hybrid (some remote, some in-person)
#
#                                     CodingActivities  \
# ResponseId
# 1                                                NaN
# 2           Hobby;Contribute to open-source projects
# 3                                              Hobby
#
#                                                     EdLevel  \
# ResponseId
# 1                                                       NaN
# ...

# %%
sch_df = pd.read_csv('survey_results_schema.csv', index_col='qname')

# %%
sch_df.drop(['qid'], inplace=True, axis=1)

# %%
sch_df
# Out:
#                                                                question  \
# qname
# S0                    <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo                                              Browser Meta Info
# S1                    <span style="font-size:22px; font-family: aria...
# MainBranch            Which of the following options best describes ...
# Employment            Which of the following best describes your cur...
# RemoteWork            Which best describes your current work situation?
# CodingActivities      Which of the following best describes the code...
# S2                    <span style="font-size:22px; font-family: aria...
# EdLevel               Which of the following best describes the high...
# LearnCode             How did you learn to code? Select all that apply.
# LearnCodeOnline       What online resources do you use to learn to c...
# LearnCodeCoursesCert  What online courses or certifications do you u...
# ...

# %%
sch_df.loc['Knowledge_1', 'question']
# Out:
# 'I have interactions with people outside of my immediate team.'

# %%
sch_df.sort_index(inplace=True)

# %%
sch_df
# Out:
#                                                                question  \
# qname
# Accessibility         Which of the following describe you, if any? P...
# Age                                                   What is your age?
# Blockchain            How favorable are you about blockchain, crypto...
# BuyNewTool            When buying a new tool or software, how do you...
# CodingActivities      Which of the following best describes the code...
# CompFreq               Is that compensation weekly, monthly, or yearly?
# CompTotal             What is your current total compensation (salar...
# Country               Where do you live? <span style="font-weight: b...
# Currency              Which currency do you use day-to-day? If your ...
# Database              Which <b>database environments </b>have you do...
# DevType               Which of the following describes your current ...
# EdLevel               Which of the following best describes the high...
# ...
